# %%
import os
import re
from turtle import title

dir_path = r"c:\Users\NAN\Desktop\Just Dhamma\justdhamma.github.io\_transcripts\hillside-hermitage"

for filename in os.listdir(dir_path):
    # print(filename)
    if filename.__contains__('transcript'):
        print(filename)
    
    filepath = os.path.join(dir_path, filename)
    with open(filepath, 'r', encoding='utf-8') as f:
        content = f.read()
        
        frontmatter = 

        episode = 
        title =
# Out:
#   Cell In[5], line 16
#     episode =
#               ^
# SyntaxError: invalid syntax

# %%
content = '''
        ---
        name: dipak
        age: 20
        address: surkhet
        ---
        dfsdff
        dfsdfsdfs
        dfsffsd
        '''

frontmatter = content[5:10]

print(frontmatter)
# Out:
#     -

# %%
string = "oiiii---jjjjjj---"

print(string.index('---'))
# Out:
# 5
